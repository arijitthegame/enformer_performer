# %%
import fast_attention 
import fast_attention_sonnet
import tensorflow as tf

# %%
att = fast_attention.Attention(16,2,.1)

# %%
q = tf.random.uniform(shape=[3,4,2])
k = tf.random.uniform(shape=[3,4,2])
v = tf.random.uniform(shape=[3,4,2])
# Out:
# 2021-07-19 23:50:56.480778: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-19 23:50:56.481149: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
att(q,k,v, training=False)
# Out:
# <tf.Tensor: shape=(3, 4, 16), dtype=float32, numpy=
# array([[[-0.18411647, -0.04235095,  0.22154942, -0.0676275 ,
#          -0.27551848, -0.5635143 , -0.212014  ,  0.0985232 ,
#          -0.21964404,  0.34877256,  0.4430136 ,  0.057391  ,
#          -0.14075099, -0.19116862, -0.06790448, -0.24783257],
#         [-0.16661733, -0.04078298,  0.22091903, -0.07945228,
#          -0.25376654, -0.5837271 , -0.19992425,  0.07957981,
#          -0.21986705,  0.36471668,  0.4538509 ,  0.06387669,
#          -0.12456175, -0.19875494, -0.05377022, -0.25271928],
#         [-0.11854018, -0.03875249,  0.1777253 , -0.11206058,
#          -0.22173025, -0.6214761 , -0.17039028,  0.02582404,
#          -0.2220481 ,  0.41227418,  0.4840657 ,  0.08351396,
#          -0.06989419, -0.14529051, -0.03501548, -0.26005796],
#         [-0.12096417, -0.03864601,  0.1836499 , -0.11040035,
#          -0.22083527, -0.62115324, -0.1715461 ,  0.02869858,
#          -0.22178757,  0.4095154 ,  0.482482  ,  0.0823511 ,
#          -0.07357418, -0.1547017 , -0.03414551, -0.2602298 ]],
#
#        [[-0.05017148, -0.00308289,  0.22550425, -0.08459865,
#          -0.03288278, -0.4107364 , -0.09286852,  0.03671142,
#          -0.11734495,  0.22017966,  0.27914393,  0.02583246,
#          -0.05486989, -0.29358456,  0.05670908, -0.17856151],
#         [-0.0689787 , -0.00873695,  0.1935632 , -0.06799865,
#          -0.0735691 , -0.37284115, -0.10331861,  0.04823392,
#          -0.11735676,  0.20570114,  0.26420355,  0.02447199,
#          -0.06490102, -0.23289664,  0.02541927, -0.16436853],
#         [-0.04248536, -0.00214455,  0.22684234, -0.09052387,
#          -0.02303438, -0.42168614, -0.08815115,  0.02904495,
#          -0.11787143,  0.22797145,  0.28520587,  0.02840731,
#          -0.04795018, -0.29900756,  0.06369136, -0.18182479],
#         [-0.05274541, -0.00410593,  0.21932128, -0.08218814,
#          -0.03948626, -0.4049823 , -0.094184  ,  0.03770838,
#          -0.11747053,  0.21861114,  0.2771779 ,  0.02604439,
#          -0.05579552, -0.2823318 ,  0.0515197 , -0.17623654]],
#
#        [[-0.1004234 , -0.0101829 ,  0.2436691 , -0.07724344,
#          -0.11106966, -0.4473792 , -0.14241132,  0.08227362,
#          -0.14572571,  0.24079324,  0.3206159 ,  0.0211299 ,
#          -0.09459475, -0.28325233,  0.02127667, -0.20315322],
#         [-0.06859218, -0.00626547,  0.2511262 , -0.10325836,
#          -0.070508  , -0.49793527, -0.12374397,  0.05047179,
#          -0.14932765,  0.2762231 ,  0.34942335,  0.03223899,
#          -0.06585158, -0.30800578,  0.0509989 , -0.21890685],
#         [-0.0855219 , -0.01980426,  0.16970076, -0.0813574 ,
#          -0.13400161, -0.44410965, -0.12626304,  0.03978771,
#          -0.1517153 ,  0.2735359 ,  0.33452752,  0.04472411,
#          -0.06249457, -0.17155868, -0.00365952, -0.19177432],
#         [-0.06768292, -0.00628041,  0.25040966, -0.10390525,
#          -0.0698551 , -0.4990147 , -0.12313416,  0.04926733,
#          -0.14946918,  0.2773914 ,  0.35022426,  0.03275216,
#          -0.06481043, -0.3072201 ,  0.05138437, -0.21912754]]],
#       dtype=float32)>

# %%
d = fast_attention_sonnet.DenseEinsum(output_shape=[3, 4])

# %%
q
# Out:
# <tf.Tensor: shape=(3, 4, 2), dtype=float32, numpy=
# array([[[0.9463624 , 0.875126  ],
#         [0.6477612 , 0.25701904],
#         [0.67324865, 0.420282  ],
#         [0.02375185, 0.3321097 ]],
#
#        [[0.75548947, 0.91775477],
#         [0.8243774 , 0.16390991],
#         [0.39590907, 0.7915007 ],
#         [0.67535925, 0.9815544 ]],
#
#        [[0.40092528, 0.14905155],
#         [0.9759133 , 0.04588139],
#         [0.5841346 , 0.34549594],
#         [0.7322705 , 0.4629532 ]]], dtype=float32)>

# %%
d(q)
# Out:
# <tf.Tensor: shape=(3, 4, 3, 4), dtype=float32, numpy=
# array([[[[ 0.26772243, -0.33337727,  0.63552725,  0.48005474],
#          [ 0.40005016,  0.26231515,  0.6457148 ,  0.94156957],
#          [-0.67562425,  0.14656454, -0.7160816 ,  0.56872886]],
#
#         [[ 0.07729029, -0.19906929,  0.42007044,  0.3764237 ],
#          [ 0.13574243,  0.0796403 ,  0.35510367,  0.5175619 ],
#          [-0.30052814,  0.03474991, -0.374956  ,  0.2110861 ]],
#
#         [[ 0.12778302, -0.21994245,  0.44328588,  0.36981142],
#          [ 0.20292065,  0.1275156 ,  0.40797976,  0.5947644 ],
#          [-0.38486546,  0.06548133, -0.44129217,  0.2991925 ]],
#
#         [[ 0.10281402, -0.03477535,  0.02949236, -0.03133635],
#          [ 0.13526757,  0.09719048,  0.09499071,  0.13873476],
#          [-0.16380255,  0.06314408, -0.12243303,  0.17587945]]],
#
#
#        [[[ 0.28162107, -0.2847968 ,  0.516915  ,  0.35257837],
#          [ 0.407843  ,  0.27342692,  0.5711452 ,  0.83298963],
#          [-0.6431109 ,  0.15901928, -0.6454612 ,  0.56820387]],
#
#         [[ 0.04780256, -0.23945177,  0.52748007,  0.5018854 ],
#          [ 0.10686368,  0.0536808 ,  0.4104715 ,  0.59811544],
#          [-0.30520436,  0.01293613, -0.42222682,  0.18360934]],
#
#         [[ 0.2438039 , -0.17568912,  0.2844456 ,  0.14132388],
#          [ 0.33912072,  0.23401472,  0.37819386,  0.55177855],
#          [-0.48405853,  0.14287753, -0.442849  ,  0.4595834 ]],
#
#         [[ 0.30167848, -0.26831087,  0.46912485,  0.29264134],
#          [ 0.42964894,  0.2915022 ,  0.5515008 ,  0.8044428 ],
#          [-0.6511956 ,  0.17304921, -0.63127506,  0.5919022 ]]],
#
#
#        [[[ 0.04473106, -0.12235808,  0.25956053,  0.2343864 ],
#          [ 0.07996749,  0.04636301,  0.21724053,  0.31661814],
#          [-0.18126097,  0.01958543, -0.22869778,  0.12542449]],
#
#         [[ 0.01068462, -0.2708521 ,  0.6179717 ,  0.61486644],
#          [ 0.06668558,  0.02026495,  0.44828796,  0.6530748 ],
#          [-0.29115763, -0.01309299, -0.4499385 ,  0.14016038]],
#
#         [[ 0.10493395, -0.18919885,  0.3837743 ,  0.32354116],
#          [ 0.16832672,  0.10504088,  0.34911177,  0.50892967],
#          [-0.3248533 ,  0.05314113, -0.37642893,  0.24960876]],
#
#         [[ 0.1407906 , -0.23972027,  0.48240194,  0.40141672],
#          [ 0.22306259,  0.14039664,  0.4452262 ,  0.649068  ],
#          [-0.42136413,  0.072339  , -0.48194137,  0.3284577 ]]]],
#       dtype=float32)>

# %%
at = fast_attention_sonnet.Attention(16,2,.1)

# %%
at(q,k,v, training=False)
# Out:
# (2, 2, 8)
# tf.Tensor(
# [[[-0.04083711 -0.50937396  0.2947538   0.49913263  0.48731947
#    -0.488171    0.45297062  0.20162433]
#   [-0.35118735 -0.48102605 -0.5052095  -0.38140315  0.04238015
#     0.2910176   0.3258443  -0.2536764 ]]
#
#  [[-0.07063007  0.33799034 -0.14918494  0.22882527  0.24527758
#     0.04973143 -0.4673724  -0.13839388]
#   [-0.26980132 -0.301239   -0.3147586   0.32021296 -0.4681593
#     0.13827688 -0.3241405  -0.18332595]]], shape=(2, 2, 8), dtype=float32)
# (2, 2, 8)
# tf.Tensor(
# [[[ 0.4707868   0.5379522   0.50483024  0.13152081  0.45028973
#    -0.4282465   0.18887854 -0.1595712 ]
#   [ 0.00403202 -0.47473267 -0.43934038  0.00993156 -0.51828873
#     0.5397513  -0.10779637  0.31429094]]
#
#  [[ 0.49867475  0.22138429  0.31532717 -0.44958743 -0.37905023
#     0.29970998  0.03218246  0.10364318]
#   [-0.43025178 -0.05316362  0.4451005   0.50197065  0.48194587
#     0.04536825  0.00480729 -0.4130259 ]]], shape=(2, 2, 8), dtype=float32)
# None
# abc,cde->abde
# (2, 2, 8)
# tf.Tensor(
# [[[-0.20902017 -0.2764366  -0.41601425  0.19344395 -0.17613384
#     0.11611855 -0.19656709  0.44961601]
#   [-0.05688497 -0.46028188 -0.08691415  0.2644078   0.17310303
#     0.30794585 -0.18213055 -0.0326975 ]]
#
#  [[-0.17565668 -0.4616332  -0.3704589  -0.09995383 -0.08290878
#     0.24784815  0.05337411  0.09888393]
#   [ 0.40133506 -0.3227444  -0.43274117  0.5006193  -0.02131408
#     0.10756093 -0.04588324  0.18019825]]], shape=(2, 2, 8), dtype=float32)
# (2, 2, 8)
# tf.Tensor(
# [[[ 0.5037668  -0.36568278 -0.4055913  -0.17138988  0.21331924
#    -0.4973975  -0.269101    0.03499478]
#   [ 0.3443601  -0.22887713 -0.12086895 -0.12435341  0.4307062
#     0.25082767  0.2507438  -0.14485663]]
#
#  [[-0.07926083 -0.47628614  0.15950459 -0.4287456   0.2927972
#     0.2644542  -0.13825023 -0.37427425]
#   [-0.20033154  0.31336248 -0.15625039 -0.02313197  0.4662863
#    -0.18080053 -0.2405144  -0.09117341]]], shape=(2, 2, 8), dtype=float32)
# None
# abc,cde->abde
# (2, 2, 8)
# tf.Tensor(
# [[[ 0.30897003  0.50925326 -0.27623564  0.47413766 -0.47181797
#     0.5068556  -0.06931257  0.33224356]
#   [-0.1838581   0.00417513 -0.17938232 -0.31837076  0.16063291
#     0.15865463 -0.01018018 -0.03309888]]
#
#  [[ 0.22909993  0.10836911  0.22293174 -0.3063822  -0.07602581
#    -0.32298794  0.09279621 -0.29723862]
#   [ 0.03917998  0.4031446  -0.42815274 -0.11888504  0.44135076
#    -0.36219755  0.14935762  0.24220496]]], shape=(2, 2, 8), dtype=float32)
# (2, 2, 8)
# tf.Tensor(
# [[[-0.14194453  0.0660091  -0.35136482  0.24804068 -0.5389006
#    -0.5211764   0.05465126 -0.11968309]
#   [-0.20276582  0.02165031 -0.5073549  -0.5007437   0.3617844
#     0.4723909  -0.14777958  0.02170908]]
#
#  [[ 0.4267462  -0.35112792  0.54654765 -0.09554756  0.2953707
#     0.480147   -0.4379751   0.33272022]
#   [-0.17003098 -0.1728108   0.2278617   0.53678346 -0.0432722
#     0.03260779  0.44923538  0.22523242]]], shape=(2, 2, 8), dtype=float32)
# None
# abc,cde->abde
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/sx/jbrq5h7x65jbz0n1wlryvx6m0000gn/T/ipykernel_26231/2124974869.py in <module>
# ----> 1 at(q,k,v, training=False)
#
# ~/enformer_performer/env/lib/python3.7/site-packages/sonnet/src/utils.py in _decorate_unbound_method(self, *args, **kwargs)
#      87       def _decorate_unbound_method(self, *args, **kwargs):
#      88         bound_method = f.__get__(self, self.__class__)  # pytype: disable=attribute-error
# ---> 89         return decorator_fn(bound_method, self, args, kwargs)
#      90
#      91       return _decorate_unbound_method
#
# ~/enformer_performer/env/lib/python3.7/site-packages/sonnet/src/base.py in wrap_with_name_scope(method, instance, args, kwargs)
#     270     # snt.Module enters the module name scope for all methods. To disable this
#     271     # for a particular method annotate it with `@snt.no_name_scope`.
# --> 272     return method(*args, **kwargs)
#     273
#     274
#
# ~/enformer_performer/performer/tf_version/fast_attention_sonnet.py in __call__(self, query_input, source_input, bias, training, cache, decode_loop_step)
#     327     attention_output = favor_attention(query, key, value,
#     328                                        self.kernel_transformation, self.causal,
# --> 329                                        projection_matrix)
#     330     attention_output = self.output_dense_layer(attention_output)
#     331     return attention_output
#
# ~/enformer_performer/performer/tf_version/fast_attention.py in favor_attention(query, key, value, kernel_transformation, causal, projection_matrix)
#     340   """
#     341   query_prime = kernel_transformation(query, True,
# --> 342                                       projection_matrix)  # [B,L,H,M]
#     343   key_prime = kernel_transformation(key, False, projection_matrix)  # [B,L,H,M]
#     344   query_prime = tf.transpose(query_prime, [1, 0, 2, 3])  # [L,B,H,M]
#
# ~/enformer_performer/performer/tf_version/fast_attention.py in softmax_kernel_transformation(data, is_query, projection_matrix, numerical_stabilizer)
#     172   data = data_normalizer * data
#     173   ratio = 1.0 / tf.math.sqrt(
# --> 174       tf.dtypes.cast(projection_matrix.shape[0], tf.float32))
#     175   data_dash = tf.einsum("blhd,md->blhm", data, projection_matrix)
#     176   diag_data = tf.math.square(data)
#
# AttributeError: 'NoneType' object has no attribute 'shape'
